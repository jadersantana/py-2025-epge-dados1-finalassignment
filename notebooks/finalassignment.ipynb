# %% [markdown]
# # FGV EPGE - Escola de Pós-Graduação em Economia
# ---
# ## Mestrado Profissional em Economia
# ### Decisões Baseadas em Dados I - 2025-4
# ---
# #### Aluno: Rafael Martins de Souza (rafael.souza@fgv.br)
# ##### Doutor em Economia (EPGE, 2009), Mestre (UFRJ, 2003) e Bacharel em Estatística (ENCE, 2000).
# ---

# %% [markdown]
# # Guia do Trabalho Final de Decisões Baseadas em Dados I
#
#
# Este manual tem como objetivo guiar os alunos na elaboração do trabalho final, requisito para aprovação na disciplina Decisões Baseadas em Dados I do Mestrado e Doutorado em Economia e Finanças da Escola de Pós-Graduação em Economia.
#
# ## Estrutura
#
# O trabalho final deve ser entregue em um único arquivo do Google Colab NoteBook compartilhado no próprio Google Colab com o nome no formato "DecisoesBaseadasemDados-NomedoAluno.ipynb". A pasta deverá ser compartilhada com os seguintes emails: rafaelmartinsdesouza@gmail.com e rodrigok.leal@gmail.com.
#
# O trabalho final deve ser pensado do seguinte modo:
#
# - Faça uma pergunta a ser respondida a partir de uma análise de dados;
# - Escolha base de dados que possa ser útil para responder a sua pergunta;
# - Pense nas técnicas de *Machine Learning* que você considera mais adequadas para responder a sua perguntdal
# - Organize o documento final de acordo com a estrutura abaixo.

# %% [markdown]
# # Apresentação

# %% [markdown]
# Apresente aqui a sua ideia e conte sobre a sua motivação em analisar a base dados que você escolheu. você pode até usar umas figuras bonitinhas para ilustrar o seu notebook.

# %% [markdown]
# <img src="https://i.imgur.com/8DZunAQ.jpg" alt="Meatball Sub" width="250"/>

# %% [markdown]
# # Introdução

# %% [markdown]
# Introduza a base de dados que você escolheu. Use células de código para importar as bibliotecas que você vai precisar e ler os dados que você usará. Use células de texto para reportar e comentar os seus avanços.

# %%
import os
import pandas as pd
import zipfile
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Desenvolvimento

# %% [markdown]
# ## Descrição da Base de Dados
#
# Descreva a base de dados utilizada, com informações sobre fonte, forma de acesso, número de exemplos (observações), número de características (variáveis explicativas) etc.

# %% [markdown]
# ## Análise Exploratória de Dados (AED)
#
# Faça uma detalhada AED no seu conjunto de dados para obter *insights* sobre a pergunta que você quer responder.
#
# Tome cuidado para pensar em como você irá analisar a base de treinamento e de teste.

# %% [markdown]
# ## Preparação de Dados

# %% [markdown]
# Faça todo o exercício de preparação de dados para que você possa rodar os modelos de *ML*.

# %% [markdown]
# Use células de código para desenvolver o seu trabalho. use células de texto para reportar os seus achados. Faça uso das medidas resumo e dos gráficos aprendidos durante as aulas.

# %% [markdown]
# # Algoritmos e Metodologia
#
# Nesta seção você deve falar sobre os algoritmos de *ML* que você usou, apresentar os códigos com comenários sobre cada uma das etapas.

# %% [markdown]
# # Discussão (se você pensar que é necessário)

# %% [markdown]
# # Conclusão

# %% [markdown]
# Escreva suas conclusões sobre o problema que você tratou.

# %% [markdown]
# # Referências

# %% [markdown]
# Declare todas as referências que você utilizou no seu trabalho: códigos, notebooks, livros, artigos científicos, blogs etc.
#
# Declare também os trechos de código que você criou com ajuda de LLMs.
